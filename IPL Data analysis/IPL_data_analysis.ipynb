# %% [markdown]
# 🔍 Tasks You Can Do:
# Total matches played
#
# Most successful team (most wins)
#
# Most matches played by a team
#
# Player with most 'Player of the Match' awards
#
# Most matches hosted at a stadium
#
# How many times each team won the toss
#
# Compare toss winner vs match winner

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("02_Cricket_data.csv")
df
# Out:
#       season       id                                          name  \
# 0        NaN  1370350          Chennai Super Kings v Gujarat Titans
# 1        NaN  1370351         Lucknow Super Giants v Mumbai Indians
# 2        NaN  1370352                                     TBC v TBC
# 3        NaN  1370353                                     TBC v TBC
# 4     2023.0  1359544  Royal Challengers Bangalore v Gujarat Titans
# ...      ...      ...                                           ...
# 1027  2008.0   336012  Royal Challengers Bangalore v Mumbai Indians
# 1028  2008.0   336019            Kings XI Punjab v Rajasthan Royals
# 1029  2008.0   336038           Delhi Daredevils v Rajasthan Royals
# 1030  2008.0   336039         Chennai Super Kings v Kings XI Punjab
# 1031  2008.0   336040        Chennai Super Kings v Rajasthan Royals
#
#       short_name                                        description home_team  \
# ...

# %%
Most_winner = df["winner"].value_counts()
most_winning_team = Most_winner.idxmax()  # Team with max wins
most_win_count = Most_winner.max()        # Number of wins

print(f"\n Most Winning Team: {most_winning_team} with {most_win_count} wins")
# Out:
#  Most Winning Team: MI with 140 wins

# %%
a = df["home_team"].value_counts()
b = df["away_team"].value_counts()
h = (a+b)
most_played_team = h.idxmax()
most_played_count= h.max()
print(f"\n Most match played by a team : {most_played_team} with {most_played_count} times. ")
# Out:
#  Most match played by a team : MI with 247 times.

# %%
Most_player_of_the_Match = df["pom"].value_counts()
most_times_player =Most_player_of_the_Match.idxmax() 
most_time_no_of_pom = Most_player_of_the_Match.max()        

print(f"\n Most time player of the match is : {most_times_player} pom is {most_time_no_of_pom} times")
# Out:
#  Most time player of the match is : AB de Villiers pom is 25 times

# %%
Most_hosted_stadium = df["venue_name"].value_counts()
stadium_name =Most_hosted_stadium.idxmax() 
no_of_time_hosted = Most_hosted_stadium.max()        

print(f"\n Most time hosted stadium is : {stadium_name} its hosted {no_of_time_hosted} times")
# Out:
#  Most time hosted stadium is : Wankhede Stadium, Mumbai its hosted 111 times

# %%
most_toss_win = df["toss_won"].value_counts()
most_toss_win
# Out:
# toss_won
# MI         131
# SRH        124
# DC         123
# KKR        119
# CSK        117
# RCB        114
# RR         109
# KXIP        94
# PWI         20
# GT          18
# GL          15
# RPS         13
# LSG         10
# Kochi        8
# no toss      7
# PBKS         5
# Name: count, dtype: int64

# %%
df["match_and_toss_winner"]=df["toss_won"]==df["winner"]
result=df["match_and_toss_winner"].value_counts()

match_toss_win = result.get(True)
toss_but_not_match = result.get(False)

print(f"toss and match both win : {match_toss_win} times")
print(f"toss win but not match  : {toss_but_not_match} times")
# Out:
# toss and match both win : 522 times
# toss win but not match  : 510 times
